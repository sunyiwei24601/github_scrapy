# %%
import requests
import json
import random
from lxml import etree
import re
import pymongo

# %%
url = 'https://github.com/abhisingla280/ethereum-lists'
contributors_url = 'https://github.com/MyEtherWallet/ethereum-lists/graphs/contributors-data'
code_frequency_url = 'https://github.com/abhisingla280/ethereum-lists/graphs/code-frequency-data'
issues_url = 'https://github.com/MyEtherWallet/ethereum-lists/issues'
headers = {
          'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36',
          'Accept': 'text/html,application/json',
#           'Cookie': '_ga=GA1.2.1415588079.1525289744; _octo=GH1.1.388384250.1525289744; user_session=H2h7q6Syt-X4cKiuB-odGoo5JwwQnPrHYmPrHV6obZAEyECB; __Host-user_session_same_site=H2h7q6Syt-X4cKiuB-odGoo5JwwQnPrHYmPrHV6obZAEyECB; logged_in=yes; dotcom_user=sunyiwei24601; has_recent_activity=1; tz=Asia%2FShanghai; _gat=1; _gh_sess=...--c9add1697f7ed767122e88c8919abb4b869d7baa',
          'Connection': 'keep-alive',
#           'Accept-Language': 'zh-CN,zh;q=0.9',
          'X-Requested-With': 'XMLHttpRequest',
}

# %%
a = requests.get(url=issues_url,headers=headers)
print(a.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://assets-cdn.github.com">
#   <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#
#
#
#   <link crossorigin="anonymous" media="all" integrity="sha512-qQ+v+W1uJYfDMrQ/cwCVI+AGTsn1yi4rCU6KX45obe52BoF+WiHNeQ11u63iJA05vyivY57xNbhAsyK4/j1ZIQ==" rel="stylesheet" href="https://assets-cdn.github.com/assets/frameworks-01356238c65ce56a395237b592b58668.css" />
# ...

# %%
selector = etree.HTML(a.text)
open_content = selector.xpath('//*[@id="js-issues-toolbar"]/div/div[1]/a[1]/text()')[1]
closed_content = selector.xpath('//*[@id="js-issues-toolbar"]/div/div[1]/a[2]/text()')[1]

# %%
closed_content.strip()
# Out:
# '18 Closed'

# %%
contributions = requests.get(url=contributors_url, headers=headers
                            )
j = json.loads(contributions.text)
def find_user(a,name):
    for i in a:
        if i['author']['login'] == name:
            return i

# %%
u = find_user(j, '409H')
w=u['weeks']
num_a=0
num_d=0
num_c=0
for i in w:
    num_a += i['a']
    num_d += i['d']
    num_c += i['c']

# %%
codes = requests.get(url=code_frequency_url, headers=headers).text
c = json.loads(codes)

# %%
import sys 
sys.path.append(r'C:\\Users\\Carl\\PycharmProjects')
from Gitrating.connect_tools import  *

# %%
cursor = get_cursor('sss')
names = list(cursor.find().limit(100))
contributions_url = 'https://github.com/{nm}/graphs/contributors-data'
contribution_list = []
for i  in names:
    nm=i['full_name']
    contribution_list.append(contributions_url.format(nm=nm))
for i  in names:
    nm=i['full_name']

    contribution_list.append(contributions_url.format(nm=nm))

# %%
import requests
headers = {
    'User-Agent':       'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36',
    'Accept':           'text/html,application/json',
    # 'Cookie'         : '_ga=GA1.2.1415588079.1525289744; _octo=GH1.1.388384250.1525289744; user_session=H2h7q6Syt-X4cKiuB-odGoo5JwwQnPrHYmPrHV6obZAEyECB; __Host-user_session_same_site=H2h7q6Syt-X4cKiuB-odGoo5JwwQnPrHYmPrHV6obZAEyECB; logged_in=yes; dotcom_user=sunyiwei24601; has_recent_activity=1; tz=Asia%2FShanghai; _gat=1; _gh_sess=...--c9add1697f7ed767122e88c8919abb4b869d7baa',
    'Connection':       'keep-alive',
      #'Accept-Language': 'zh-CN,zh;q=0.9',
    'X-Requested-With': 'XMLHttpRequest',
}
import json
ips = []
def refresh_proxies():
    url = 'http://piping.mogumiao.com/proxy/api/get_ip_al?appKey=fe709d1800124643ae77710b640' \
          '7a482&count=10&expiryDate=0&format=1&newLine=2'
    s = requests.get(url)
    print(s.text)
    t = s.text
    j = json.loads(t)
    global ips
    ips = []
    for i in j['msg']:
        ips.append(i['ip']+':'+i['port'])
import random

# %%
from requests.exceptions import ReadTimeout
import traceback
refresh_proxies()
for url in contribution_list:
    
    try:
        a = requests.get(url=url, headers=headers, proxies={'http': random.choice(ips)}, timeout=20)
    except ReadTimeout as e:
        print('time_out_problem')
    else:
        traceback.extract_stack()
    print(a)
    try:
        j=json.loads(a.text)
        print('correct')
    except:
        print(j[0]['author'])
        print('error')
# Out:
# {"code":"0","msg":[{"port":"22591","ip":"49.72.80.138"},{"port":"29346","ip":"14.116.105.157"},{"port":"24484","ip":"113.103.116.134"},{"port":"20938","ip":"115.50.18.24"},{"port":"32466","ip":"114.104.145.51"},{"port":"23014","ip":"27.204.158.102"},{"port":"28777","ip":"222.142.156.82"}]}
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# ...

# %%
for url in contribution_list:
    try:
        a = requests.get(url=url, headers=headers, timeout=20)
    except ReadTimeout as e:
        print('time_out_problem')
    else:
        traceback.extract_stack()
    print(a)
    try:
        j=json.loads(a.text)
        print('correct')
    except:
        print(j[0]['author'])
        print('error')
# Out:
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# <Response [200]>
# correct
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
# ...
